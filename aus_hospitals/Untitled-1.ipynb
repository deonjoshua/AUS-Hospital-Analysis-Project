# %%
# import necessary libraries
import os

from flask import (
    Flask,
    render_template,
    jsonify,
    request,
    redirect)

import sqlalchemy
from sqlalchemy.ext.automap import automap_base
from sqlalchemy.orm import Session
from sqlalchemy import create_engine, func, inspect

import pandas as pd

# %%
#################################################
# Database Setup
#################################################
engine = create_engine("sqlite:///Hospital_Data.sqlite")

# reflect an existing database into a new model
Base = automap_base()
# reflect the tables
Base.prepare(autoload_with=engine)

# get all the classes
ed_triage = Base.classes.ED_Triage
ed_on_time = Base.classes.ED_on_time
ed_waiting = Base.classes.ED_waiting
ed_waiting_peer_group = Base.classes.ED_waiting_Peer_Group
hospitals = Base.classes.Hospitals
peer_group = Base.classes.Peer_Group

session = Session(engine)

# convert to dataframes
ed_triage_df = pd.read_sql(session.query(ed_triage).statement,session.bind)
ed_on_time_df = pd.read_sql(session.query(ed_on_time).statement,session.bind)
ed_waiting_df = pd.read_sql(session.query(ed_waiting).statement,session.bind)
ed_waiting_peer_group_df = pd.read_sql(session.query(ed_waiting_peer_group).statement,session.bind)
hospitals_df = pd.read_sql(session.query(hospitals).statement,session.bind)
peer_group_df = pd.read_sql(session.query(peer_group).statement,session.bind)
peer_group_df['Peer_Group_ID'] = peer_group_df['Peer_group_ID']

# merge dataframes/clean the data

merge = ed_on_time_df.merge(ed_triage_df[['Triage_ID','Triage_category','treatment_required_in']])

merge1 = hospitals_df.merge(peer_group_df[['Peer_Group_ID','Peer_group_name']])
merge2 = merge1.merge(ed_waiting_df[['Hospital_ID','Patient_cohort','No_of_presentations','Median_time_in_ED','Year']])
merge2['No_of_presentations_waiting'] = merge2['No_of_presentations']
merge2['Median_time_in_ED_waiting'] = merge2['Median_time_in_ED']

cleaned_df1 = merge[['Hospital_ID','Year','Triage_category','No_of_presentations','Percentage_of_patients_seen_on_time']]
cleaned_df1['No_of_presentations_ontime'] = cleaned_df1['No_of_presentations']

merge3 = peer_group_df.merge(ed_waiting_peer_group_df[['Peer_group_ID','Year','Patient_cohort','Avg_Wait_time']])
merge2 = merge2.merge(merge3[['Peer_group_ID','Patient_cohort','Avg_Wait_time']])

cleaned_df2 = merge2[['Hospital_ID','Hospital_Name','Latitude','Longitude','State', 'Sector', 'Year','Patient_cohort','Peer_group_name','No_of_presentations_waiting','Median_time_in_ED_waiting']]

joined_df = cleaned_df2.merge(cleaned_df1[['Hospital_ID','Year','Triage_category','No_of_presentations_ontime','Percentage_of_patients_seen_on_time']])


print(joined_df)
# Out:
# /Users/joshbrodrick/opt/anaconda3/envs/PythonData/lib/python3.7/site-packages/ipykernel_launcher.py:40: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#        Hospital_ID                        Hospital_Name   Latitude  \
# 0            H0014  The Children's Hospital at Westmead -33.801554
# 1            H0014  The Children's Hospital at Westmead -33.801554
# 2            H0014  The Children's Hospital at Westmead -33.801554
# 3            H0014  The Children's Hospital at Westmead -33.801554
# 4            H0014  The Children's Hospital at Westmead -33.801554
# ...            ...                                  ...        ...
# 144823       H0738               Alice Springs Hospital -23.705758
# 144824       H0738               Alice Springs Hospital -23.705758
# 144825       H0738               Alice Springs Hospital -23.705758
# 144826       H0738               Alice Springs Hospital -23.705758
# 144827       H0738               Alice Springs Hospital -23.705758
#
#          Longitude State  Sector  Year                  Patient_cohort  \
# 0       150.991759   NSW  Public  2020                    All patients
# 1       150.991759   NSW  Public  2020                    All patients
# 2       150.991759   NSW  Public  2020                    All patients
# 3       150.991759   NSW  Public  2020                    All patients
# 4       150.991759   NSW  Public  2020                    All patients
# ...            ...   ...     ...   ...                             ...
# 144823  133.878064    NT  Public  2021  Subsequently admitted patients
# 144824  133.878064    NT  Public  2021  Subsequently admitted patients
# 144825  133.878064    NT  Public  2021  Subsequently admitted patients
# 144826  133.878064    NT  Public  2021  Subsequently admitted patients
# 144827  133.878064    NT  Public  2021  Subsequently admitted patients
#
#                  Peer_group_name No_of_presentations_waiting  \
# 0           Children's hospitals                       55497
# 1           Children's hospitals                       55497
# 2           Children's hospitals                       55497
# 3           Children's hospitals                       55497
# 4           Children's hospitals                       55497
# ...                          ...                         ...
# 144823  Large regional hospitals                       19043
# 144824  Large regional hospitals                       19043
# 144825  Large regional hospitals                       19043
# 144826  Large regional hospitals                       19043
# 144827  Large regional hospitals                       19043
#
#        Median_time_in_ED_waiting Triage_category  No_of_presentations_ontime  \
# 0                           2.97       Emergency                        3244
# 1                           2.97      Non-Urgent                         508
# 2                           2.97   Resuscitation                         642
# 3                           2.97     Semi-Urgent                       32892
# 4                           2.97          Urgent                       15273
# ...                          ...             ...                         ...
# 144823                      5.07       Emergency                        7279
# 144824                      5.07      Non-Urgent                        1159
# 144825                      5.07   Resuscitation                         180
# 144826                      5.07     Semi-Urgent                       13313
# 144827                      5.07          Urgent                       17799
#
#        Percentage_of_patients_seen_on_time
# 0                                      64%
# 1                                      87%
# 2                                     100%
# 3                                      78%
# 4                                      83%
# ...                                    ...
# 144823                                 79%
# 144824                                 93%
# 144825                                100%
# 144826                                 64%
# 144827                                 65%
#
# [144828 rows x 14 columns]

# %%
print(merge3)
# Out:
#    Peer_group_ID                Peer_group_name Peer_Group_ID  Year  \
# 0              1                       National             1  2020
# 1              1                       National             1  2021
# 2              1                       National             1  2020
# 3              1                       National             1  2021
# 4              1                       National             1  2020
# 5              1                       National             1  2021
# 6              2                Major hospitals             2  2020
# 7              2                Major hospitals             2  2021
# 8              2                Major hospitals             2  2020
# 9              2                Major hospitals             2  2021
# 10             2                Major hospitals             2  2020
# 11             2                Major hospitals             2  2021
# 12             3   Large metropolitan hospitals             3  2020
# 13             3   Large metropolitan hospitals             3  2020
# 14             3   Large metropolitan hospitals             3  2020
# 15             3   Large metropolitan hospitals             3  2021
# 16             3   Large metropolitan hospitals             3  2021
# 17             3   Large metropolitan hospitals             3  2021
# 18             4  Medium metropolitan hospitals             4  2020
# 19             4  Medium metropolitan hospitals             4  2020
# 20             4  Medium metropolitan hospitals             4  2020
# 21             4  Medium metropolitan hospitals             4  2021
# 22             4  Medium metropolitan hospitals             4  2021
# 23             4  Medium metropolitan hospitals             4  2021
# 24             5       Large regional hospitals             5  2021
# 25             5       Large regional hospitals             5  2021
# 26             5       Large regional hospitals             5  2021
# 27             5       Large regional hospitals             5  2020
# 28             5       Large regional hospitals             5  2020
# 29             5       Large regional hospitals             5  2020
# 30             6      Medium regional hospitals             6  2020
# 31             6      Medium regional hospitals             6  2020
# 32             6      Medium regional hospitals             6  2020
# 33             6      Medium regional hospitals             6  2021
# 34             6      Medium regional hospitals             6  2021
# 35             6      Medium regional hospitals             6  2021
# 36             7                Small hospitals             7  2021
# 37             7                Small hospitals             7  2021
# 38             7                Small hospitals             7  2021
# 39             7                Small hospitals             7  2020
# 40             7                Small hospitals             7  2020
# 41             7                Small hospitals             7  2020
# 42             8           Children's hospitals             8  2020
# 43             8           Children's hospitals             8  2020
# 44             8           Children's hospitals             8  2020
# 45             8           Children's hospitals             8  2021
# 46             8           Children's hospitals             8  2021
# 47             8           Children's hospitals             8  2021
# 48             9                       Unpeered             9  2021
# 49             9                       Unpeered             9  2021
# 50             9                       Unpeered             9  2021
# 51             9                       Unpeered             9  2020
# 52             9                       Unpeered             9  2020
# 53             9                       Unpeered             9  2020
#
#                         Patient_cohort  Avg_Wait_time
# 0                         All patients           7.50
# 1                         All patients           8.00
# 2   Not subsequently admitted patients           5.58
# 3   Not subsequently admitted patients           5.88
# 4       Subsequently admitted patients          11.45
# 5       Subsequently admitted patients          12.95
# 6                         All patients           8.43
# 7                         All patients           9.10
# 8   Not subsequently admitted patients           5.93
# 9   Not subsequently admitted patients           6.25
# 10      Subsequently admitted patients          11.98
# 11      Subsequently admitted patients          13.83
# 12                        All patients           8.15
# 13  Not subsequently admitted patients           6.12
# 14      Subsequently admitted patients          11.82
# 15                        All patients           8.70
# 16  Not subsequently admitted patients           6.40
# 17      Subsequently admitted patients          13.07
# 18                        All patients           7.03
# 19  Not subsequently admitted patients           5.92
# 20      Subsequently admitted patients           9.60
# 21                        All patients           7.15
# 22  Not subsequently admitted patients           6.05
# 23      Subsequently admitted patients          10.05
# 24                        All patients           8.78
# 25  Not subsequently admitted patients           5.87
# 26      Subsequently admitted patients          15.62
# 27                        All patients           8.13
# 28  Not subsequently admitted patients           5.52
# 29      Subsequently admitted patients          13.62
# 30                        All patients           5.88
# 31  Not subsequently admitted patients           4.83
# 32      Subsequently admitted patients           9.12
# 33                        All patients           6.33
# 34  Not subsequently admitted patients           5.17
# 35      Subsequently admitted patients          10.23
# 36                        All patients           5.33
# 37  Not subsequently admitted patients           4.60
# 38      Subsequently admitted patients           8.68
# 39                        All patients           4.98
# 40  Not subsequently admitted patients           4.25
# 41      Subsequently admitted patients           7.73
# 42                        All patients           5.70
# 43  Not subsequently admitted patients           4.77
# 44      Subsequently admitted patients           8.13
# 45                        All patients           5.97
# 46  Not subsequently admitted patients           5.18
# 47      Subsequently admitted patients           8.17
# 48                        All patients           0.00
# 49  Not subsequently admitted patients           0.00
# 50      Subsequently admitted patients           0.00
# 51                        All patients           0.00
# 52  Not subsequently admitted patients           0.00
# 53      Subsequently admitted patients           0.00

# %%
SELECT "Hospitals"."Hospital_ID" AS "Hospitals_Hospital_ID", "Hospitals"."Hospital_Name" AS "Hospitals_Hospital_Name", "Hospitals"."Latitude" AS "Hospitals_Latitude", "Hospitals"."Longitude" AS "Hospitals_Longitude", "Hospitals"."Sector" AS "Hospitals_Sector", "Hospitals"."Peer_Group_ID" AS "Hospitals_Peer_Group_ID", "Hospitals"."State" AS "Hospitals_State", "Hospitals"."LHN" AS "Hospitals_LHN", "Hospitals"."PHN" AS "Hospitals_PHN", "Peer_Group"."Peer_group_ID" AS "Peer_Group_Peer_group_ID", "Peer_Group"."Peer_group_name" AS "Peer_Group_Peer_group_name", "ED_waiting"."Hospital_ID" AS "ED_waiting_Hospital_ID", "ED_waiting"."Year" AS "ED_waiting_Year", "ED_waiting"."Patient_cohort" AS "ED_waiting_Patient_cohort", "ED_waiting"."No_of_presentations" AS "ED_waiting_No_of_presentations", "ED_waiting"."Median_time_in_ED" AS "ED_waiting_Median_time_in_ED", "ED_on_time"."Hospital_ID" AS "ED_on_time_Hospital_ID", "ED_on_time"."Year" AS "ED_on_time_Year", "ED_on_time"."Triage_ID" AS "ED_on_time_Triage_ID", "ED_on_time"."No_of_presentations" AS "ED_on_time_No_of_presentations", "ED_on_time"."Percentage_of_patients_seen_on_time" AS "ED_on_time_Percentage_of_patients_seen_on_time", "ED_Triage"."Triage_ID" AS "ED_Triage_Triage_ID", "ED_Triage"."Triage_category" AS "ED_Triage_Triage_category", "ED_Triage".treatment_required_in AS "ED_Triage_treatment_required_in" 
FROM "Hospitals" JOIN "Peer_Group" ON "Hospitals"."Peer_Group_ID" = "Peer_Group"."Peer_group_ID" JOIN "ED_waiting" ON "Hospitals"."Hospital_ID" = "ED_waiting"."Hospital_ID" JOIN "ED_on_time" ON "Hospitals"."Hospital_ID" = "ED_on_time"."Hospital_ID" JOIN "ED_Triage" ON "ED_on_time"."Triage_ID" = "ED_Triage"."Triage_ID"

# %% [markdown]
# column_names = [column.name for column in merged_table.columns]
